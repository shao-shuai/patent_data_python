# %%
import numpy as np
import pandas as pd
import requests
import json
import datetime

# %%
#date = datetime.datetime.now()
#date.strftime("%Y") + '-' + date.strftime("%m") + '-' + date.strftime("%d")

# %%
#construct API URL
url = "https://ptabdata.uspto.gov/ptab-api/trials?filingDateFrom=2019-04-08&filingDateTo=2019-04-14&limit=100"

# %%
#request data
ptab = requests.get(url).json()

# %%
#generate dataframe
ptab_df = pd.DataFrame(ptab['results'])
ptab_nolin= ptab_df.loc[:, ptab_df.columns!='links']
#ptab_nolin = ptab_nolin.sort_values(by='filingDate')

# %%
#link patent number to google patent
def make_clickable(number):
    return '<a href=https://patents.google.com/patent/US{}>{}</a>'.format(number, number)
df = ptab_nolin.drop(['petitionerPartyName', 'trialName'], axis = 1)
df.style.format({'patentNumber':make_clickable})
# Out:
# <style  type="text/css" >
# </style><table id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >applicationNumber</th>        <th class="col_heading level0 col1" >filingDate</th>        <th class="col_heading level0 col2" >lastModifiedDatetime</th>        <th class="col_heading level0 col3" >patentNumber</th>        <th class="col_heading level0 col4" >patentOwnerName</th>        <th class="col_heading level0 col5" >prosecutionStatus</th>        <th class="col_heading level0 col6" >trialNumber</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row0_col0" class="data row0 col0" >10635664</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row0_col1" class="data row0 col1" >2019-04-11</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row0_col2" class="data row0 col2" >2019-04-11T21:10:57</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row0_col3" class="data row0 col3" ><a href=https://patents.google.com/patent/US6999463>6999463</a></td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row0_col4" class="data row0 col4" >Christie et al</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row0_col5" class="data row0 col5" >Submitted</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row0_col6" class="data row0 col6" >IPR2019-00853</td>
#             </tr>
#             <tr>
#                         <th id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row1_col0" class="data row1 col0" >10682013</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row1_col1" class="data row1 col1" >2019-04-10</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row1_col2" class="data row1 col2" >2019-04-10T20:50:26</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row1_col3" class="data row1 col3" ><a href=https://patents.google.com/patent/US7324534>7324534</a></td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row1_col4" class="data row1 col4" >Christie et al</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row1_col5" class="data row1 col5" >Submitted</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row1_col6" class="data row1 col6" >IPR2019-00854</td>
#             </tr>
#             <tr>
#                         <th id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row2_col0" class="data row2 col0" >14032414</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row2_col1" class="data row2 col1" >2019-04-08</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row2_col2" class="data row2 col2" >2019-04-08T15:29:18</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row2_col3" class="data row2 col3" ><a href=https://patents.google.com/patent/US9100634>9100634</a></td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row2_col4" class="data row2 col4" >ESENLIK et al</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row2_col5" class="data row2 col5" >Submitted</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row2_col6" class="data row2 col6" >IPR2019-00883</td>
#             </tr>
#             <tr>
#                         <th id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row3_col0" class="data row3 col0" >15357136</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row3_col1" class="data row3 col1" >2019-04-10</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row3_col2" class="data row3 col2" >2019-04-10T18:31:17</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row3_col3" class="data row3 col3" ><a href=https://patents.google.com/patent/US9757040>9757040</a></td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row3_col4" class="data row3 col4" >ISLAM, Mohammed N.</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row3_col5" class="data row3 col5" >Submitted</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row3_col6" class="data row3 col6" >IPR2019-00910</td>
#             </tr>
#             <tr>
#                         <th id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row4_col0" class="data row4 col0" >15686198</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row4_col1" class="data row4 col1" >2019-04-10</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row4_col2" class="data row4 col2" >2019-04-10T17:06:50</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row4_col3" class="data row4 col3" ><a href=https://patents.google.com/patent/US9861286>9861286</a></td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row4_col4" class="data row4 col4" >ISLAM, Mohammed N.</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row4_col5" class="data row4 col5" >Submitted</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row4_col6" class="data row4 col6" >IPR2019-00911</td>
#             </tr>
#             <tr>
#                         <th id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row5_col0" class="data row5 col0" >15212549</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row5_col1" class="data row5 col1" >2019-04-10</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row5_col2" class="data row5 col2" >2019-04-10T17:10:51</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row5_col3" class="data row5 col3" ><a href=https://patents.google.com/patent/US9885698>9885698</a></td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row5_col4" class="data row5 col4" >ISLAM, Mohammed N.</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row5_col5" class="data row5 col5" >Submitted</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row5_col6" class="data row5 col6" >IPR2019-00912</td>
#             </tr>
#             <tr>
#                         <th id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row6_col0" class="data row6 col0" >14875709</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row6_col1" class="data row6 col1" >2019-04-10</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row6_col2" class="data row6 col2" >2019-04-10T18:34:34</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row6_col3" class="data row6 col3" ><a href=https://patents.google.com/patent/US9651533>9651533</a></td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row6_col4" class="data row6 col4" >Islam, Mohammed N.</td>
#                         <td id="T_3eeb75fa_5fe4_11e9_ad31_7085c289d556row6_col5" class="data row6 col5" >Submitted</td>

# %%
ptab
# Out:
# {'metadata': {'limit': 100,
#   'offset': 0,
#   'count': 38,
#   'links': [{'rel': 'self',
#     'href': 'https://ptabdata.uspto.gov/ptab-api/trials?filingDateFrom=2019-04-08&filingDateTo=2019-04-14&limit=100'}]},
#  'results': [{'trialNumber': 'IPR2019-00853',
#    'applicationNumber': '10635664',
#    'patentNumber': '6999463',
#    'petitionerPartyName': 'Frontier Communications Corporation',
#    'patentOwnerName': 'Christie et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-11',
#    'lastModifiedDatetime': '2019-04-11T21:10:57',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00853'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00853/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00853/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00854',
#    'applicationNumber': '10682013',
#    'patentNumber': '7324534',
#    'petitionerPartyName': 'Frontier Communications Corporation',
#    'patentOwnerName': 'Christie et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-10',
#    'lastModifiedDatetime': '2019-04-10T20:50:26',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00854'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00854/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00854/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00883',
#    'applicationNumber': '14032414',
#    'patentNumber': '9100634',
#    'petitionerPartyName': 'Unified Patents Inc.',
#    'patentOwnerName': 'ESENLIK et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-08',
#    'lastModifiedDatetime': '2019-04-08T15:29:18',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00883'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00883/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00883/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00910',
#    'applicationNumber': '15357136',
#    'patentNumber': '9757040',
#    'petitionerPartyName': 'Apple Inc.',
#    'patentOwnerName': 'ISLAM, Mohammed N.',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-10',
#    'lastModifiedDatetime': '2019-04-10T18:31:17',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00910'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00910/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00910/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00911',
#    'applicationNumber': '15686198',
#    'patentNumber': '9861286',
#    'petitionerPartyName': 'Apple Inc.',
#    'patentOwnerName': 'ISLAM, Mohammed N.',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-10',
#    'lastModifiedDatetime': '2019-04-10T17:06:50',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00911'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00911/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00911/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00912',
#    'applicationNumber': '15212549',
#    'patentNumber': '9885698',
#    'petitionerPartyName': 'Apple Inc.',
#    'patentOwnerName': 'ISLAM, Mohammed N.',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-10',
#    'lastModifiedDatetime': '2019-04-10T17:10:51',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00912'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00912/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00912/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00913',
#    'applicationNumber': '14875709',
#    'patentNumber': '9651533',
#    'petitionerPartyName': 'Apple Inc.',
#    'patentOwnerName': 'Islam, Mohammed N.',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-10',
#    'lastModifiedDatetime': '2019-04-10T18:34:34',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00913'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00913/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00913/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00914',
#    'applicationNumber': '15686198',
#    'patentNumber': '9861286',
#    'petitionerPartyName': 'Apple Inc.',
#    'patentOwnerName': 'ISLAM, Mohammed N.',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-10',
#    'lastModifiedDatetime': '2019-04-10T14:36:16',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00914'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00914/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00914/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00915',
#    'applicationNumber': '15212549',
#    'patentNumber': '9885698',
#    'petitionerPartyName': 'Apple Inc.',
#    'patentOwnerName': 'ISLAM, Mohammed N.',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-10',
#    'lastModifiedDatetime': '2019-04-10T14:20',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00915'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00915/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00915/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00916',
#    'applicationNumber': '14875709',
#    'patentNumber': '9651533',
#    'petitionerPartyName': 'Apple Inc.',
#    'patentOwnerName': 'Islam, Mohammed N.',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-10',
#    'lastModifiedDatetime': '2019-04-10T14:15:39',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00916'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00916/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00916/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00917',
#    'applicationNumber': '15357136',
#    'patentNumber': '9757040',
#    'petitionerPartyName': 'Apple Inc.',
#    'patentOwnerName': 'ISLAM, Mohammed N.',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-10',
#    'lastModifiedDatetime': '2019-04-10T20:05:08',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00917'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00917/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00917/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00918',
#    'applicationNumber': '13463540',
#    'patentNumber': '8369298',
#    'petitionerPartyName': 'Apple Inc.',
#    'patentOwnerName': 'LIN, Daniel J.',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-12',
#    'lastModifiedDatetime': '2019-04-12T16:23:56',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00918'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00918/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00918/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00930',
#    'applicationNumber': '14721540',
#    'patentNumber': '9774703',
#    'petitionerPartyName': 'PayPal, Inc.',
#    'patentOwnerName': 'McNulty, Scott',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-08',
#    'lastModifiedDatetime': '2019-04-08T20:45:46',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00930'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00930/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00930/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00931',
#    'applicationNumber': '14721540',
#    'patentNumber': '9774703',
#    'petitionerPartyName': 'PayPal, Inc.',
#    'patentOwnerName': 'McNulty, Scott',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-08',
#    'lastModifiedDatetime': '2019-04-08T21:23:06',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00931'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00931/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00931/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00932',
#    'applicationNumber': '09912931',
#    'patentNumber': '7036020',
#    'petitionerPartyName': 'Micron Technology, Inc.',
#    'patentOwnerName': 'Thibadeau, Robert H.',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T21:36:25',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00932'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00932/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00932/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00935',
#    'applicationNumber': '15470099',
#    'patentNumber': '9945202',
#    'petitionerPartyName': 'FMC Technologies, Inc.',
#    'patentOwnerName': 'June et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-12',
#    'lastModifiedDatetime': '2019-04-12T18:29:37',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00935'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00935/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00935/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00944',
#    'applicationNumber': '10135019',
#    'patentNumber': '6937191',
#    'petitionerPartyName': 'Kathrein USA, Inc.',
#    'patentOwnerName': 'Puente Baliarda, Carles',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T21:13:05',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00944'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00944/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00944/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00945',
#    'applicationNumber': '10135019',
#    'patentNumber': '6937191',
#    'petitionerPartyName': 'Kathrein USA, Inc.',
#    'patentOwnerName': 'Puente Baliarda, Carles',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T21:13:56',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00945'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00945/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00945/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00946',
#    'applicationNumber': '10988261',
#    'patentNumber': '7250918',
#    'petitionerPartyName': 'Kathrein USA, Inc.',
#    'patentOwnerName': 'Baliarda, Carles Puente',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T21:15:01',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00946'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00946/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00946/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00947',
#    'applicationNumber': '10988261',
#    'patentNumber': '7250918',
#    'petitionerPartyName': 'Kathrein USA, Inc.',
#    'patentOwnerName': 'Baliarda, Carles Puente',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T21:15:48',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00947'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00947/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00947/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00948',
#    'applicationNumber': '11803782',
#    'patentNumber': '7557768',
#    'petitionerPartyName': 'Kathrein USA, Inc.',
#    'patentOwnerName': 'Puente Baliarda et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T21:16:48',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00948'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00948/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00948/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00949',
#    'applicationNumber': '11803782',
#    'patentNumber': '7557768',
#    'petitionerPartyName': 'Kathrein USA, Inc.',
#    'patentOwnerName': 'Puente Baliarda et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T21:17:45',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00949'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00949/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00949/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00950',
#    'applicationNumber': '12476308',
#    'patentNumber': '7932870',
#    'petitionerPartyName': 'Kathrein USA, Inc.',
#    'patentOwnerName': 'Baliarda et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T21:18:42',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00950'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00950/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00950/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00951',
#    'applicationNumber': '12476308',
#    'patentNumber': '7932870',
#    'petitionerPartyName': 'Kathrein USA, Inc.',
#    'patentOwnerName': 'Baliarda et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T21:19:30',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00951'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00951/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00951/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00952',
#    'applicationNumber': '13044831',
#    'patentNumber': '8228256',
#    'petitionerPartyName': 'Kathrein USA, Inc.',
#    'patentOwnerName': 'Baliarda et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T21:20:24',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00952'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00952/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00952/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00953',
#    'applicationNumber': '13044831',
#    'patentNumber': '8228256',
#    'petitionerPartyName': 'Kathrein USA, Inc.',
#    'patentOwnerName': 'Baliarda et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T21:21:11',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00953'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00953/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00953/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00954',
#    'applicationNumber': '12089751',
#    'patentNumber': '8497814',
#    'petitionerPartyName': 'Kathrein USA, Inc.',
#    'patentOwnerName': 'Puente et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T13:20:35',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00954'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00954/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00954/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00955',
#    'applicationNumber': '12089751',
#    'patentNumber': '8497814',
#    'petitionerPartyName': 'Kathrein USA, Inc.',
#    'patentOwnerName': 'Puente et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T13:21:30',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00955'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00955/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00955/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00956',
#    'applicationNumber': '14282488',
#    'patentNumber': '9450305',
#    'petitionerPartyName': 'Kathrein USA, Inc.',
#    'patentOwnerName': 'Puente et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T13:22:19',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00956'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00956/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00956/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00957',
#    'applicationNumber': '14282488',
#    'patentNumber': '9450305',
#    'petitionerPartyName': 'Kathrein USA, Inc.',
#    'patentOwnerName': 'Puente et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T13:22:58',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00957'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00957/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00957/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00958',
#    'applicationNumber': '11719611',
#    'patentNumber': '7848439',
#    'petitionerPartyName': 'Apple Inc.',
#    'patentOwnerName': 'She et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-08',
#    'lastModifiedDatetime': '2019-04-08T17:35:18',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00958'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00958/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00958/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00959',
#    'applicationNumber': '11719611',
#    'patentNumber': '7848439',
#    'petitionerPartyName': 'Apple Inc.',
#    'patentOwnerName': 'She et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-08',
#    'lastModifiedDatetime': '2019-04-08T17:34:11',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00959'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00959/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00959/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00960',
#    'applicationNumber': '10690298',
#    'patentNumber': 'RE38844',
#    'petitionerPartyName': 'MAHLE FILTER SYSTEMS NORTH AMERICA, INC.',
#    'patentOwnerName': 'Hiltzik et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-09',
#    'lastModifiedDatetime': '2019-04-09T14:48:50',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00960'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00960/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00960/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00961',
#    'applicationNumber': '12783405',
#    'patentNumber': '8238532',
#    'petitionerPartyName': 'Next Caller Inc.',
#    'patentOwnerName': 'Cox et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-11',
#    'lastModifiedDatetime': '2019-04-11T11:00:03',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00961'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00961/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00961/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00962',
#    'applicationNumber': '12783405',
#    'patentNumber': '8238532',
#    'petitionerPartyName': 'Next Caller Inc.',
#    'patentOwnerName': 'Cox et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-11',
#    'lastModifiedDatetime': '2019-04-11T11:32:53',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00962'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00962/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00962/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00963',
#    'applicationNumber': '15045020',
#    'patentNumber': '9871913',
#    'petitionerPartyName': 'Next Caller Inc.',
#    'patentOwnerName': 'SAITAWDEKAR et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-11',
#    'lastModifiedDatetime': '2019-04-11T13:05:28',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00963'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00963/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00963/documents.zip'}]},
#   {'trialNumber': 'IPR2019-00972',
#    'applicationNumber': '10242385',
#    'patentNumber': '6626858',
#    'petitionerPartyName': 'Ivantis, Inc.',
#    'patentOwnerName': 'Lynch et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-12',
#    'lastModifiedDatetime': '2019-04-12T15:22:59',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00972'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00972/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/IPR2019-00972/documents.zip'}]},
#   {'trialNumber': 'PGR2019-00045',
#    'trialName': 'Petition for Post Grant Review of US 10071852',
#    'applicationNumber': '15496796',
#    'patentNumber': '10071852',
#    'petitionerPartyName': 'Red Diamond, Inc.',
#    'patentOwnerName': 'Stewart et al',
#    'prosecutionStatus': 'Submitted',
#    'filingDate': '2019-04-10',
#    'lastModifiedDatetime': '2019-04-10T11:22:41',
#    'links': [{'rel': 'self',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/PGR2019-00045'},
#     {'rel': 'documents',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/PGR2019-00045/documents'},
#     {'rel': 'documents-download',
#      'href': 'https://ptabdata.uspto.gov/ptab-api/trials/PGR2019-00045/documents.zip'}]}]}
