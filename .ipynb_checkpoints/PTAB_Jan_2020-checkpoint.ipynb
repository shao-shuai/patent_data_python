# %%
import numpy as np
import pandas as pd
import requests
import json
import datetime

# %%
url = "https://developer.uspto.gov/ptab-api/proceedings?proceedingFilingFromDate=2020-01-01&proceedingFilingToDate=2020-01-31&recordTotalQuantity=200&sortOrderCategory=proceedingFilingDate"

# %%
ptab = requests.get(url).json()
ptab = pd.DataFrame(ptab['results'])

# %%
ptab.shape
# Out:
# (80, 16)

# %%
ptab=ptab.iloc[:, 0:16]

# %%
def make_clickable(number):
    return '<a href=https://patents.google.com/patent/US{}>{}</a>'.format(number, number)
#df = ptab_df.drop(['prosecutionStatus', 'trialName'], axis = 1)
#df.style.format({'patentNumber':make_clickable})

# %%
df = ptab[['proceedingNumber', 'respondentPatentNumber', 'petitionerPartyName', 'petitionerCounselName', 'respondentPatentOwnerName', 'respondentPartyName', 'respondentCounselName','respondentTechnologyCenterNumber', 'respondentGroupArtUnitNumber',
       'proceedingFilingDate']]

# %%
df.index+=1
df.index
# Out:
# RangeIndex(start=1, stop=81, step=1)

# %%
#df.reset_index(drop=True).style.format({'respondentPatentNumber':make_clickable})
df.style.format({'respondentPatentNumber':make_clickable})
# Out:
# <style  type="text/css" >
# </style><table id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >proceedingNumber</th>        <th class="col_heading level0 col1" >respondentPatentNumber</th>        <th class="col_heading level0 col2" >petitionerPartyName</th>        <th class="col_heading level0 col3" >petitionerCounselName</th>        <th class="col_heading level0 col4" >respondentPatentOwnerName</th>        <th class="col_heading level0 col5" >respondentPartyName</th>        <th class="col_heading level0 col6" >respondentCounselName</th>        <th class="col_heading level0 col7" >respondentTechnologyCenterNumber</th>        <th class="col_heading level0 col8" >respondentGroupArtUnitNumber</th>        <th class="col_heading level0 col9" >proceedingFilingDate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdlevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow0_col0" class="data row0 col0" >IPR2020-00385</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow0_col1" class="data row0 col1" ><a href=https://patents.google.com/patent/US6954634>6954634</a></td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow0_col2" class="data row0 col2" >SAMSUNG ELECTRONICS AMERICA, INC.</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow0_col3" class="data row0 col3" >Naveen Modi</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow0_col4" class="data row0 col4" >Bucknell et al</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow0_col5" class="data row0 col5" >Uniloc 2017 LLC</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow0_col6" class="data row0 col6" >Ryan Loveless</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow0_col7" class="data row0 col7" >2600</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow0_col8" class="data row0 col8" >2682</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow0_col9" class="data row0 col9" >01-02-2020</td>
#             </tr>
#             <tr>
#                         <th id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdlevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow1_col0" class="data row1 col0" >IPR2020-00386</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow1_col1" class="data row1 col1" ><a href=https://patents.google.com/patent/US7353417>7353417</a></td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow1_col2" class="data row1 col2" >Nuvoton Technology Corporation</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow1_col3" class="data row1 col3" >E. Robert Yoches</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow1_col4" class="data row1 col4" >Desuche et al</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow1_col5" class="data row1 col5" >Microchip Technology Incorporated</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow1_col6" class="data row1 col6" >Bruce W. Slayden II</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow1_col7" class="data row1 col7" >2100</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow1_col8" class="data row1 col8" >2115</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow1_col9" class="data row1 col9" >01-02-2020</td>
#             </tr>
#             <tr>
#                         <th id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdlevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow2_col0" class="data row2 col0" >IPR2020-00352</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow2_col1" class="data row2 col1" ><a href=https://patents.google.com/patent/US9414066>9414066</a></td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow2_col2" class="data row2 col2" >Unified Patents, LLC</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow2_col3" class="data row2 col3" >David Cavanaugh</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow2_col4" class="data row2 col4" >Norkin et al</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow2_col5" class="data row2 col5" >Velos Media, LLC</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow2_col6" class="data row2 col6" >Brent Bumgardner</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow2_col7" class="data row2 col7" >2400</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow2_col8" class="data row2 col8" >2481</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow2_col9" class="data row2 col9" >01-02-2020</td>
#             </tr>
#             <tr>
#                         <th id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdlevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow3_col0" class="data row3 col0" >IPR2020-00383</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow3_col1" class="data row3 col1" ><a href=https://patents.google.com/patent/US7126515>7126515</a></td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow3_col2" class="data row3 col2" >Nuvoton Technology Corporation</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow3_col3" class="data row3 col3" >E. Robert Yoches</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow3_col4" class="data row3 col4" >Kris, Bryan  </td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow3_col5" class="data row3 col5" >Microchip Technology Incorporated</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow3_col6" class="data row3 col6" >Bruce W. Slayden II</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow3_col7" class="data row3 col7" >2800</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow3_col8" class="data row3 col8" >2819</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow3_col9" class="data row3 col9" >01-02-2020</td>
#             </tr>
#             <tr>
#                         <th id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdlevel0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow4_col0" class="data row4 col0" >IPR2020-00384</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow4_col1" class="data row4 col1" ><a href=https://patents.google.com/patent/US6954634>6954634</a></td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow4_col2" class="data row4 col2" >SAMSUNG ELECTRONICS AMERICA, INC.</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow4_col3" class="data row4 col3" >Naveen Modi</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow4_col4" class="data row4 col4" >Bucknell et al</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow4_col5" class="data row4 col5" >Uniloc 2017 LLC</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow4_col6" class="data row4 col6" >Ryan Loveless</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow4_col7" class="data row4 col7" >2600</td>
#                         <td id="T_5e8f5cd2_4647_11ea_94ef_acbc32902dcdrow4_col8

# %%
ax = df['petitionerPartyName'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for each Owner Name")
ax.set_xlabel("Petitioner")
ax.set_ylabel("Count of filings")
# Out:
# Text(0, 0.5, 'Count of filings')
