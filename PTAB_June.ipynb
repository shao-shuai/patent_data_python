# %%
import numpy as np
import pandas as pd
import requests
import json
import datetime

# %%
url1 = "https://ptabdata.uspto.gov/ptab-api/trials?filingDateFrom=2019-06-01&filingDateTo=2019-06-20&limit=100"
url2 = "https://ptabdata.uspto.gov/ptab-api/trials?filingDateFrom=2019-06-21&filingDateTo=2019-06-30&limit=100"

# %%
ptab1 = requests.get(url1).json()
ptab2 = requests.get(url2).json()

# %%
ptab_df_1 = pd.DataFrame(ptab1['results'])
ptab_df_2 = pd.DataFrame(ptab2['results'])

# %%
ptab_df = pd.concat([ptab_df_1,ptab_df_2])
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
ptab_df = ptab_df.loc[:, ptab_df.columns!='links']

# %%
def make_clickable(number):
    return '<a href=https://patents.google.com/patent/US{}>{}</a>'.format(number, number)
df = ptab_df.drop(['prosecutionStatus', 'trialName'], axis = 1)
#df.style.format({'patentNumber':make_clickable})

# %%
df.reset_index(drop=True).style.format({'patentNumber':make_clickable})
# Out:
# <style  type="text/css" >
# </style><table id="T_859a195c_9c57_11e9_8af3_f85971433982" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >accordedFilingDate</th>        <th class="col_heading level0 col1" >applicationNumber</th>        <th class="col_heading level0 col2" >filingDate</th>        <th class="col_heading level0 col3" >lastModifiedDatetime</th>        <th class="col_heading level0 col4" >patentNumber</th>        <th class="col_heading level0 col5" >patentOwnerName</th>        <th class="col_heading level0 col6" >petitionerPartyName</th>        <th class="col_heading level0 col7" >trialNumber</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_859a195c_9c57_11e9_8af3_f85971433982level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row0_col0" class="data row0 col0" >nan</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row0_col1" class="data row0 col1" >15674122</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row0_col2" class="data row0 col2" >2019-06-03</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row0_col3" class="data row0 col3" >2019-06-18T16:45:31</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row0_col4" class="data row0 col4" ><a href=https://patents.google.com/patent/US10004173>10004173</a></td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row0_col5" class="data row0 col5" >Garner et al</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row0_col6" class="data row0 col6" >Precision Planting, LLC</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row0_col7" class="data row0 col7" >IPR2019-01054</td>
#             </tr>
#             <tr>
#                         <th id="T_859a195c_9c57_11e9_8af3_f85971433982level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row1_col1" class="data row1 col1" >14516350</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row1_col2" class="data row1 col2" >2019-06-05</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row1_col3" class="data row1 col3" >2019-06-25T13:32:49</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row1_col4" class="data row1 col4" ><a href=https://patents.google.com/patent/US9336517>9336517</a></td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row1_col5" class="data row1 col5" >Prasad et al</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row1_col6" class="data row1 col6" >Wells Fargo Bank, N.A.</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row1_col7" class="data row1 col7" >IPR2019-01081</td>
#             </tr>
#             <tr>
#                         <th id="T_859a195c_9c57_11e9_8af3_f85971433982level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row2_col0" class="data row2 col0" >2019-06-05</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row2_col1" class="data row2 col1" >12545127</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row2_col2" class="data row2 col2" >2019-06-05</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row2_col3" class="data row2 col3" >2019-06-25T13:22:51</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row2_col4" class="data row2 col4" ><a href=https://patents.google.com/patent/US8977571>8977571</a></td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row2_col5" class="data row2 col5" >BUECHE et al</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row2_col6" class="data row2 col6" >Wells Fargo Bank, N.A.</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row2_col7" class="data row2 col7" >IPR2019-01082</td>
#             </tr>
#             <tr>
#                         <th id="T_859a195c_9c57_11e9_8af3_f85971433982level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row3_col0" class="data row3 col0" >nan</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row3_col1" class="data row3 col1" >12549443</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row3_col2" class="data row3 col2" >2019-06-05</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row3_col3" class="data row3 col3" >2019-06-25T14:36:43</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row3_col4" class="data row3 col4" ><a href=https://patents.google.com/patent/US8699779>8699779</a></td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row3_col5" class="data row3 col5" >PRASAD et al</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row3_col6" class="data row3 col6" >Wells Fargo Bank, N.A.</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row3_col7" class="data row3 col7" >IPR2019-01083</td>
#             </tr>
#             <tr>
#                         <th id="T_859a195c_9c57_11e9_8af3_f85971433982level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row4_col0" class="data row4 col0" >2019-06-04</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row4_col1" class="data row4 col1" >13548475</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row4_col2" class="data row4 col2" >2019-06-04</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row4_col3" class="data row4 col3" >2019-06-25T14:26:49</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row4_col4" class="data row4 col4" ><a href=https://patents.google.com/patent/USRE44789>RE44789</a></td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row4_col5" class="data row4 col5" >Barthel et al</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row4_col6" class="data row4 col6" >OPEC Engineering Co., LTD, dba OPECMADE Inc.</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row4_col7" class="data row4 col7" >IPR2019-01090</td>
#             </tr>
#             <tr>
#                         <th id="T_859a195c_9c57_11e9_8af3_f85971433982level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row5_col0" class="data row5 col0" >2019-06-07</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row5_col1" class="data row5 col1" >14885805</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row5_col2" class="data row5 col2" >2019-06-07</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row5_col3" class="data row5 col3" >2019-06-28T14:20:57</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row5_col4" class="data row5 col4" ><a href=https://patents.google.com/patent/US9517219>9517219</a></td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row5_col5" class="data row5 col5" >Warner et al</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row5_col6" class="data row5 col6" >Mylan Pharmaceuticals Inc.</td>
#                         <td id="T_859a195c_9c57_11e9_8af3_f85971433982row5_col7" class="data row5 col7" >IPR2019-01095</td>
#             </tr>
#             <tr>
#                         <th id="T_859a195c_9c57_11e9_8af3_f859714

# %%
ax = df['petitionerPartyName'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for each Owner Name")
ax.set_xlabel("Petitioner")
ax.set_ylabel("Count of filings")
# Out:
# Text(0, 0.5, 'Count of filings')
